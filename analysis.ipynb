# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Kareem\Desktop\ultimate_student_productivity_dataset_5000.csv')

# %%
df.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %%
df.describe()
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    20.520400     4.539594          2.478734
# std    1443.520003     2.870406     1.821665          1.177990
# min       1.000000    16.000000     0.000000          0.000000
# 25%    1250.750000    18.000000     3.250000          1.660000
# 50%    2500.500000    20.000000     4.530000          2.480000
# 75%    3750.250000    23.000000     5.760000          3.290000
# max    5000.000000    25.000000    11.840000          7.410000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.011984            2.998086      1.564514     7.016492
# std                0.983906            1.467949      1.110807     1.163692
# min                0.000000            0.000000      0.000000     4.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            5000 non-null   int64
#  1   age                   5000 non-null   int64
#  2   gender                5000 non-null   object
#  3   academic_level        5000 non-null   object
#  4   study_hours           5000 non-null   float64
#  5   self_study_hours      5000 non-null   float64
#  6   online_classes_hours  5000 non-null   float64
#  7   social_media_hours    5000 non-null   float64
#  8   gaming_hours          5000 non-null   float64
#  9   sleep_hours           5000 non-null   float64
#  10  screen_time_hours     5000 non-null   float64
#  11  exercise_minutes      5000 non-null   int64
#  12  caffeine_intake_mg    5000 non-null   int64
#  13  part_time_job         5000 non-null   int64
#  14  upcoming_deadline     5000 non-null   int64
# ...

# %%
df[['mental_health_score','productivity_score']].head(10)
# Out:
#    mental_health_score  productivity_score
# 0                   10               73.65
# 1                    3               13.70
# 2                    8               45.15
# 3                    3               20.92
# 4                    8               59.23
# 5                    8               36.20
# 6                    6               37.59
# 7                    1               45.04
# 8                   10               61.83
# 9                    9               29.06

# %%
df[['mental_health_score','productivity_score']].corr()
# Out:
#                      mental_health_score  productivity_score
# mental_health_score             1.000000            0.630605
# productivity_score              0.630605            1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.regplot(x='mental_health_score',y='productivity_score',data=df)
plt.title('the relationship between mental_health_score and productivity_score') 
plt.show()

# %%
sns.lmplot(x='mental_health_score', y='productivity_score', data=df, col='academic_level', col_order=['High School','Undergraduate','Postgraduate'])
plt.show()

# %%
df.groupby('academic_level')[['mental_health_score', 'productivity_score']].corr()
# Out:
#                                     mental_health_score  productivity_score
# academic_level
# High School    mental_health_score             1.000000            0.623913
#                productivity_score              0.623913            1.000000
# Postgraduate   mental_health_score             1.000000            0.651202
#                productivity_score              0.651202            1.000000
# Undergraduate  mental_health_score             1.000000            0.616330
#                productivity_score              0.616330            1.000000

# %%
# !pip install statsmodels

# %%
import statsmodels.api as sm

# %%
x=df['mental_health_score']
y=df['productivity_score']
x= sm.add_constant (x)

# %%
model = sm.OLS(y, x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     productivity_score   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     3300.
# Date:                Mon, 02 Mar 2026   Prob (F-statistic):               0.00
# Time:                        01:17:11   Log-Likelihood:                -19948.
# No. Observations:                5000   AIC:                         3.990e+04
# Df Residuals:                    4998   BIC:                         3.991e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  16.8722      0.400     42.144      0.000      16.087      17.657
# ...
